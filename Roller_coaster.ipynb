# %% [markdown]
# # Exploratory Data Analysis Using Python

# %% [markdown]
# ## Step 0: Importing all the essential libraries and loading dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('C:/Users/Lenovo/Downloads/Roller_Coaster_Project/coaster_db.csv')

# %% [markdown]
# ## Step 1: Data Understanding
# * Top 10 rows
# * Total No. of rows & columns
# * Brief description about Dataset
# * Name of all columns
# * Data types

# %%
df.head(10)
# Out:
#                              coaster_name            Length             Speed  \
# 0                      Switchback Railway    600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway               NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)               NaN               NaN
# 3            Loop the Loop (Coney Island)               NaN               NaN
# 4            Loop the Loop (Young's Pier)               NaN               NaN
# 5                          Cannon Coaster               NaN               NaN
# 6                           Leap-The-Dips  1,452 ft (443 m)  10 mph (16 km/h)
# 7        Figure Eight (Euclid Beach Park)               NaN               NaN
# 8                            Drop the Dip               NaN               NaN
# 9      Scenic Railway (Euclid Beach Park)               NaN               NaN
#
#                          Location     Status Opening date  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.size
# Out:
# 60872

# %% [markdown]
# ## Step 2: Data Preparation
# * Changing datatypes
# * Checking for null values
# * Dropping duplicates

# %%
df['Opening date'] = pd.to_datetime(df['Opening date'], errors='coerce', dayfirst=False)
df['Soft opening date'] = pd.to_datetime(df['Soft opening date'], errors='coerce', dayfirst=False)
df['Closing date'] = pd.to_datetime(df['Closing date'], errors='coerce', dayfirst=False)

# %%
df.isna().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      835
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                1026
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [coaster_name, Length, Speed, Location, Status, Opening date, Type, Manufacturer, Height restriction, Model, Height, Inversions, Lift/launch system, Cost, Trains, Park section, Duration, Capacity, G-force, Designer, Max vertical angle, Drop, Soft opening date, Fast Lane available, Replaced, Track layout, Fastrack available, Soft opening date.1, Closing date, Opened, Replaced by, Website, Flash Pass Available, Must transfer from wheelchair, Theme, Single rider line available, Restraint Style, Flash Pass available, Acceleration, Restraints, Name, year_introduced, latitude, longitude, Type_Main, opening_date_clean, speed1, speed2, speed1_value, speed1_unit, speed_mph, height_value, height_unit, height_ft, Inversions_clean, Gforce_clean]
# Index: []
#
# [0 rows x 56 columns]

# %%
df.drop_duplicates()
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %% [markdown]
# ## Step 3: Feature Understanding
# * Bar chart
# * Histograms
# * KDE

# %%
df['year_introduced'].value_counts()
# Out:
# year_introduced
# 1999    49
# 2000    47
# 1998    32
# 2011    31
# 2001    30
#         ..
# 1952     1
# 1956     1
# 1961     1
# 1955     1
# 1959     1
# Name: count, Length: 101, dtype: int64

# %%
ax = df['year_introduced'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years Coasters Introduced')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['speed_mph'].plot(kind='hist',
                          bins=30,
                          rwidth=0.8,
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
bx = df['coaster_name'].value_counts() \
     .head(20) \
     .plot(kind='barh',title='Coaster Name')

# %%
ax = df['speed_mph'].plot(kind='kde',
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %% [markdown]
# ## Step 4: Feature relations
# * Scatter plot
# * Heatmap correlation
# * Pairplot
# * Groupby comparisons

# %%
df.plot(kind='scatter',
        x='speed_mph',
        y='height_ft',
        title='Coaster Speed vs. Height')
# Out:
# <Axes: title={'center': 'Coaster Speed vs. Height'}, xlabel='speed_mph', ylabel='height_ft'>

# %%
ax = sns.scatterplot(x='speed_mph',
                y='height_ft',
                hue='year_introduced',
                data=df)
ax.set_title('Coaster Speed vs. Height')
# Out:
# Text(0.5, 1.0, 'Coaster Speed vs. Height')

# %%
sns.pairplot(df,
             vars=['year_introduced','speed_mph',
                   'height_ft','Inversions','Gforce_clean'],
             hue='Type_Main')

# %%
cor=df[['year_introduced','speed_mph',
    'height_ft','Inversions','Gforce_clean']].dropna().corr()
cor
# Out:
#                  year_introduced  speed_mph  height_ft  Inversions  \
# year_introduced         1.000000   0.162603   0.144997   -0.146500
# speed_mph               0.162603   1.000000   0.762588   -0.014154
# height_ft               0.144997   0.762588   1.000000   -0.083036
# Inversions             -0.146500  -0.014154  -0.083036    1.000000
# Gforce_clean            0.137225   0.579408   0.478811    0.321125
#
#                  Gforce_clean
# year_introduced      0.137225
# speed_mph            0.579408
# height_ft            0.478811
# Inversions           0.321125
# Gforce_clean         1.000000

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Modifying original file

# %%
df.to_csv('C:/Users/Lenovo/Downloads/Roller_Coaster_Project/coaster_db.csv',index=False)

# %% [markdown]
# ## Conclusion
# In this project, we analyzed the Roller Coaster dataset and explored how various attributes such as speed, height, and type are related to each other. We visualized the data using bar charts, histograms, and KDE plots, which revealed key insights like max no. of roller coasters tend to have speed between 20 to 70 mph. This analysis provides a foundation for understanding roller coaster design trends and customer preferences. While the dataset had some missing values, our findings highlight areas for deeper exploration, such as integrating external data on rider satisfaction. Future work could also involve predictive modeling to identify factors contributing to roller coaster popularity.
